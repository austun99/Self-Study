# %% [markdown]
# ## Duplicates

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('stolen_vehicles(copy).csv', header=0)

# %%
df.head()
# Out:
# 226

# %% [markdown]
# There might be duplicate rows in our data set and we want to be able to remove them
# - We can try using **df.drop_duplicates()**
#     - This function will consider all the columns and checking if everything is the same, e.g including the index, which is not fair since all indexes are unique.

# %%
df.drop_duplicates()
# Out:
#      vehicle_id     vehicle_type make_id  model_year         vehicle_desc  \
# 0             1          Trailer     623        2021             BST2021D
# 1             2     Boat Trailer     623        2021  OUTBACK BOATS FT470
# 2             3     Boat Trailer     623        2021           ASD JETSKI
# 3             4          Trailer     623        2021              MSC 7X4
# 4             5          Trailer     623        2018            D-MAX 8X5
# ..          ...              ...     ...         ...                  ...
# 221         222          Trailer     623        2016               TANDEM
# 222         223  Trailer - Heavy     623        2016                 FURN
# 223         224          Trailer     572        2016         3X2 PLATFORM
# 224         225          Trailer     623        2019            HOMEBUILT
# 225         226          Trailer     623        2019              GORILLA
#
#       color date_stolen  location_id
# 0    Silver     11/5/21        102.0
# ...

# %% [markdown]
# There is another way of using the same function, but this time we can even consider certain columns:
# - df.drop_duplicates(subset=None, keep='first', inplace=True, ignore_index=True)
#     - *subset=None* we can specify which columns to consider when making a duplicate decision e.g *subset=['vehicle_type','vehicle_desc']*
#     - *keep='first'* means that it will keep the first occurance and delete the rest
#     - *inplace=True* we will be making changes to the original data set
#     - *ignore_index=True* means that we will be ignoring the index

# %%
df.drop_duplicates(subset=None, keep='first', inplace=True, ignore_index=True)

# %%
df
# Out:
#      vehicle_id     vehicle_type make_id  model_year         vehicle_desc  \
# 0             1          Trailer     623        2021             BST2021D
# 1             2     Boat Trailer     623        2021  OUTBACK BOATS FT470
# 2             3     Boat Trailer     623        2021           ASD JETSKI
# 3             4          Trailer     623        2021              MSC 7X4
# 4             5          Trailer     623        2018            D-MAX 8X5
# ..          ...              ...     ...         ...                  ...
# 219         222          Trailer     623        2016               TANDEM
# 220         223  Trailer - Heavy     623        2016                 FURN
# 221         224          Trailer     572        2016         3X2 PLATFORM
# 222         225          Trailer     623        2019            HOMEBUILT
# 223         226          Trailer     623        2019              GORILLA
#
#       color date_stolen  location_id
# 0    Silver     11/5/21        102.0
# ...

# %%
#removing vehicles with the same 'vehicle_type' and 'make_id'
df.drop_duplicates(subset=['vehicle_type','make_id'], keep='first', inplace=True, ignore_index=True)

# %%
df
# Out:
#     vehicle_id     vehicle_type make_id  model_year          vehicle_desc  \
# 0            1          Trailer     623        2021              BST2021D
# 1            2     Boat Trailer     623        2021   OUTBACK BOATS FT470
# 2            6         Roadbike     636        2005               YZF-R6T
# 3            9          Trailer     514        2021         7X4-6" 1000KG
# 4           12          Trailer     538        2018  BRENT SMITH TRAILERS
# 5           13            Moped     629        2004                   ET2
# 6           14            Moped     NaN        2007                 TODAY
# 7           15         Roadbike     611        2007                 DL650
# 8           21         Roadbike     625        2002           THUNDERBIRD
# 9           24  Trailer - Heavy     623        2021             CT DIG 25
# 10          27          Trailer     NaN        2018   IFOR WILLIAMS CT177
# 11          32          Trailer     549        1998               TRAILER
# ...
